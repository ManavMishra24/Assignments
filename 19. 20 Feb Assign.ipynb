# %% [markdown]
# 20 FEB ASSIGNMENT

# %% [markdown]
# 1.

# %%
"""GET and POST are two of the most commonly used HTTP methods in web development. The GET method is used to request a resource from a server, while the POST method is used to submit data to a server to create or update a resource. GET requests send request parameters as part of the URL in a query string, while POST requests send parameters in the request body as key-value pairs. GET requests can be cached by the browser and are considered safe and idempotent, while POST requests cannot be cached and are considered unsafe and non-idempotent."""
# Out:
# 'GET and POST are two of the most commonly used HTTP methods in web development. The GET method is used to request a resource from a server, while the POST method is used to submit data to a server to create or update a resource. GET requests send request parameters as part of the URL in a query string, while POST requests send parameters in the request body as key-value pairs. GET requests can be cached by the browser and are considered safe and idempotent, while POST requests cannot be cached and are considered unsafe and non-idempotent.'

# %% [markdown]
# 2.

# %%
"""Request is a fundamental component in the Flask web framework for handling incoming HTTP requests from clients. When a client sends a request to a Flask application, the Flask request object is created to hold all the data related to the incoming request, including the request method (GET, POST, etc.), request headers, URL parameters, form data, and any files uploaded as part of the request."""
# Out:
# 'Request is a fundamental component in the Flask web framework for handling incoming HTTP requests from clients. When a client sends a request to a Flask application, the Flask request object is created to hold all the data related to the incoming request, including the request method (GET, POST, etc.), request headers, URL parameters, form data, and any files uploaded as part of the request.'

# %%
"""The Flask request object is used to extract information from the request, such as the user's input or the request headers, and use it to generate a response. It also provides methods for accessing and manipulating the request data, such as accessing form data or files uploaded with the request."""
# Out:
# "The Flask request object is used to extract information from the request, such as the user's input or the request headers, and use it to generate a response. It also provides methods for accessing and manipulating the request data, such as accessing form data or files uploaded with the request."

# %% [markdown]
# 3.

# %%
"""In Flask, the redirect() function is used to redirect a user to a different endpoint or URL. It's often used in web applications to guide users to the appropriate page or to handle certain situations, such as after a successful login or when an error occurs."""
# Out:
# "In Flask, the redirect() function is used to redirect a user to a different endpoint or URL. It's often used in web applications to guide users to the appropriate page or to handle certain situations, such as after a successful login or when an error occurs."

# %% [markdown]
# 4.

# %%
"""In Flask, templates are files that contain the HTML structure and other static content of a web page. They can also include placeholders for dynamic content, such as variables or loops, which are filled in with data at runtime. Flask uses a templating engine, such as Jinja2, to render templates with dynamic content."""
# Out:
# 'In Flask, templates are files that contain the HTML structure and other static content of a web page. They can also include placeholders for dynamic content, such as variables or loops, which are filled in with data at runtime. Flask uses a templating engine, such as Jinja2, to render templates with dynamic content.'

# %%
"""The render_template() function is used in Flask to generate a response object that includes a rendered template. It takes the name of the template file as its first argument, and any additional arguments are passed to the template for use as dynamic data."""
# Out:
# 'The render_template() function is used in Flask to generate a response object that includes a rendered template. It takes the name of the template file as its first argument, and any additional arguments are passed to the template for use as dynamic data.'

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def index():
        return render_template('index.html', name='indx')

# %% [markdown]
# 5.

# %% [markdown]
# ![Sum.png](attachment:30a66694-fc57-452c-99dc-8570ed71aae0.png)

# %% [markdown]
# ![Subtract.png](attachment:d32d19fc-2d19-440c-b8e2-d2d3c3014bf2.png)

# %% [markdown]
# ![Multiply.png](attachment:db97934d-5b70-48c3-b203-75e22d55dd44.png)

# %% [markdown]
# ![Divide.png](attachment:e7846a01-030b-4f9f-8b0e-1333c1658a35.png)
